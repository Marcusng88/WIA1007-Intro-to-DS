# %% [markdown]
# <a href="https://colab.research.google.com/github/Marcusng88/WIA1007-Intro-to-DS/blob/main/tutorial3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# READ MEDIAN WEEKLY EARNINGS BY SEX CSV FILE

# %%
Median_earnings = pd.read_csv("/content/sample_data/Median Weekly Earnings by Sex.csv")

# %%
Median_earnings
# Out:
#     Year  Quarter Number of workers (in thousands) - Total  \
# 0   2009        4                                   98,555
# 1   2010        1                                   98,143
# 2   2010        2                                   99,605
# 3   2010        3                                  100,412
# 4   2010        4                                   99,958
# 5   2011        1                                   99,670
# 6   2011        2                                  100,347
# 7   2011        3                                  100,495
# 8   2011        4                                  101,337
# 9   2012        1                                  102,161
# 10  2012        2                                  102,525
# 11  2012        3                                  102,587
# 12  2012        4                                  103,748
# 13  2013        1                                  103,928
# 14  2013        2                                  103,988
# ...

# %% [markdown]
# GET INFO OF THE FEATURES AND DESCRIBE SOME BASIC ANALYSIS ON THE DATA

# %%
Median_earnings.info()
Median_earnings.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 11 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Year                                                  37 non-null     int64
#  1   Quarter                                               37 non-null     int64
#  2   Number of workers (in thousands) - Total              37 non-null     object
#  3   Number of workers (in thousands) - Men                37 non-null     object
#  4   Number of workers (in thousands) - Women              37 non-null     object
#  5   Median weekly earnings (in current dollars) - Total   37 non-null     int64
#  6   Median weekly earnings (in current dollars) - Men     37 non-null     int64
#  7   Median weekly earnings (in current dollars) - Women   37 non-null     int64
# ...

# %%
total_worker = (Median_earnings["Number of workers (in thousands) - Total"].str.replace(",","").astype(int))
sum = 0
for worker in total_worker:
  sum+=int (worker)

print("the total number of sample data ,which is the number of workers is",sum*1000)
# Out:
# the total number of sample data ,which is the number of workers is 3948848000

# %% [markdown]
# PLOT THE GRAPH

# %%
Median_earnings.plot(x="Year",y = "Median weekly earnings (in current dollars) - Total",kind="scatter")

plt.show()

# %% [markdown]
# **2. Evaluate if the data is good or not. Does it have enough samples?**
#
# The data is good and comprehensive as it contains different features to analyze the data. It has enough samples of 3948848000.

# %%
print("there is",Median_earnings.shape[1],"features in the data")
# Out:
# there is 11 features in the data

# %% [markdown]
# **3. How many features does it have? Is it enough?**
#
# The features is enough as there are 11 features in the data

# %% [markdown]
# **4. How many samples/observation does it have? Is it enough?**
#
# There are 3948848000 samples in the data,yes it is enough

# %%
null_sum = Median_earnings.isnull().sum()
(null_sum)
# Out:
# Year                                                    0
# Quarter                                                 0
# Number of workers (in thousands) - Total                0
# Number of workers (in thousands) - Men                  0
# Number of workers (in thousands) - Women                0
# Median weekly earnings (in current dollars) - Total     0
# Median weekly earnings (in current dollars) - Men       0
# Median weekly earnings (in current dollars) - Women     0
# Median weekly earnings (in constant dollars) - Total    0
# Median weekly earnings (in constant dollars) - Men      0
# Median weekly earnings (in constant dollars) - Women    0
# dtype: int64

# %% [markdown]
# **5. What are the datatypes does the dataset consist of?**
#
# objects and integer

# %% [markdown]
# **6. How many columns have null values? If yes, which column, which rows**
#
# No null value

# %% [markdown]
# **7. Which column is the feature, which is the target output?**
#
# first and sixth column is the target output

# %% [markdown]
# **8. Does it have missing values? If yes, which column, which row.**
#
# No missing value

# %% [markdown]
# **9. What kind of question can be asked, should we ask. Does the dataset suits the question we are asking?**
#
# what is the relationship between the year and the median weekly earnings for the total workers.Yes,the dataset suits the question as from the graph shown,when the year increases ,the median weekly earnings increases as well. We can say that as years pass by ,the weekly medians earnings increases
