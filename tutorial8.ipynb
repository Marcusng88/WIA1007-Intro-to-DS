# %% [markdown]
# <a href="https://colab.research.google.com/github/Marcusng88/WIA1007-Intro-to-DS/blob/main/tutorial8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     275             'https://research.google.com/colaboratory/faq.html#drive-timeout'
#     276         )
# --> 277       raise ValueError('mount failed' + extra_reason)
# ...

# %% [markdown]
# #exploratory data analysis
#
# univariate
#
# bivariate
#
# multivariate
# #data initialization

# %%
import numpy as np
import pandas as pd

# %%
df_salary = pd.read_csv('/content/drive/MyDrive/Dataset/salary_cleaned.csv')
df_xtra_info = pd.read_csv('/content/drive/MyDrive/Dataset/xtra_info.csv')

# %%
print(len(df_salary))
print(len(df_xtra_info))
# Out:
# 13404
# 13404

# %%
df_master = pd.concat([df_salary,df_xtra_info],axis = 1)

# %%
print(len(df_master))
# Out:
# 13404

# %%
df_master.head()
# Out:
#    USERID           Timestamp    Age                       Industry  \
# 0    8683  4/27/2021 11:02:10  25-34   Education (Higher Education)
# 1    3880  4/27/2021 11:02:41  25-34                     Nonprofits
# 2    8898  4/27/2021 11:02:42  25-34  Accounting, Banking & Finance
# 3    4441  4/27/2021 11:03:01  45-54              Computing or Tech
# 4    7537  4/27/2021 11:03:02  35-44  Accounting, Banking & Finance
#
#                             Job title    Salary  Compensation Currency  \
# 0  Research and Instruction Librarian   55000.0           0.0      USD
# 1                     Program Manager   62000.0        3000.0      USD
# 2                  Accounting Manager   60000.0        7000.0      USD
# 3                     Systems Analyst  112000.0       10000.0      USD
# 4                   Senior Accountant   45000.0           0.0      USD
#
#          Country           State        City Overall years of experience  \
# ...

# %%
df_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13404 entries, 0 to 13403
# Data columns (total 19 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   USERID                              13404 non-null  int64
#  1   Timestamp                           13403 non-null  object
#  2   Age                                 13403 non-null  object
#  3   Industry                            13403 non-null  object
#  4   Job title                           13403 non-null  object
#  5   Salary                              13403 non-null  float64
#  6   Compensation                        13403 non-null  float64
#  7   Currency                            13403 non-null  object
#  8   Country                             13403 non-null  object
#  9   State                               13403 non-null  object
#  10  City                                13403 non-null  object
# ...

# %% [markdown]
# #analyzing each feature /columns

# %%
df_master.drop(columns = 'USERID',inplace = True)

# %%
df_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13404 entries, 0 to 13403
# Data columns (total 17 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Timestamp                           13403 non-null  object
#  1   Age                                 13403 non-null  object
#  2   Industry                            13403 non-null  object
#  3   Job title                           13403 non-null  object
#  4   Salary                              13403 non-null  float64
#  5   Compensation                        13403 non-null  float64
#  6   Currency                            13403 non-null  object
#  7   Country                             13403 non-null  object
#  8   State                               13403 non-null  object
#  9   City                                13403 non-null  object
#  10  Overall years of experience         13403 non-null  object
# ...

# %%
for feature in df_master.columns:
  len_feature = df_master[feature].nunique()
  print(f'{feature} : {len_feature}')
# Out:
# Timestamp : 12364
# Age : 7
# Industry : 717
# Job title : 7670
# Salary : 1791
# Compensation : 451
# Currency : 5
# Country : 89
# State : 106
# City : 2664
# Overall years of experience : 8
# Years of experience in current job : 8
# Education level : 6
# Gender : 5
# CGPA : 13403
# Salary_month_USD : 1791
# Special Bonus_GBP : 4673

# %%
feature_small = []
feature_large = []
for feature in df_master.columns:
  len_feature = df_master[feature].nunique()
  if len_feature < 10:
    feature_small.append([feature,len_feature])
  else:
    feature_large.append([feature,len_feature])

print('----Feature small----')
for i in feature_small:
  print(i)

print('----Feature large----')
for i in feature_large:
  print(i)
# Out:
# ----Feature small----
# ['Age', 7]
# ['Currency', 5]
# ['Overall years of experience', 8]
# ['Years of experience in current job', 8]
# ['Education level', 6]
# ['Gender', 5]
# ----Feature large----
# ['Timestamp', 12364]
# ['Industry', 717]
# ['Job title', 7670]
# ['Salary', 1791]
# ['Compensation', 451]
# ['Country', 89]
# ['State', 106]
# ['City', 2664]
# ['CGPA', 13403]
# ['Salary_month_USD', 1791]
# ['Special Bonus_GBP', 4673]

# %% [markdown]
# #analyzing small categorical variables
#
# it is easier to analyze small categorical varialbes first
#
# which category comprises most of the data
#
# what impact does a category have on the dataset

# %%
import matplotlib.pyplot as plt

# %%
column_name = []
for i in feature_small:
  column_name.append(i)

for i in column_name:
  df_master[i[0]].value_counts().plot(kind = 'bar',figsize=(5,3))
  plt.show()

# %% [markdown]
# #using subplots to improve visualization

# %%
fig, axes = plt.subplots(2,3)
i = 0
j=0
for item in feature_small:
  column_name =item[0]
  df_master[column_name].value_counts().plot(kind='bar',figsize =(15,16))

  axes[i,j].title.set_size(10)

  if (j<2):
    j+=1
  else:
    j=0
    i+=1

# %% [markdown]
# #analyzing the effect of gender on salary distribution
#
# compare distribution of salary by different gender
#
# what is the conclusion here

# %%
#method 1
x = df_master[df_master['Gender']=='Man']
y = x[x['Education level']=='College degree']
y.head()
# Out:
#              Timestamp         Age                              Industry  \
# 6   4/27/2021 11:03:09       35-44         Accounting, Banking & Finance
# 19  4/27/2021 11:04:02       25-34  Government and Public Administration
# 28  4/27/2021 11:04:29  65 or over              Property or Construction
# 43  4/27/2021 11:05:08       45-54                     Computing or Tech
# 77  4/27/2021 11:06:07       25-34          Engineering or Manufacturing
#
#                                           Job title    Salary  Compensation  \
# 6                   Manager of Information Services  100000.0           0.0
# 19  Manager of Data Integrity and Prospect Research   65000.0           0.0
# 28                                  Safety Director  104000.0       25000.0
# 43                 senior web application developer   98166.0           0.0
# 77                            Production Technician   65000.0        4000.0
#
#    Currency        Country      State          City  \
# ...

# %%
# method 2
df_master.query('Gender == "Man" and `Education level` == "College degree"').head()
# Out:
#              Timestamp         Age                              Industry  \
# 6   4/27/2021 11:03:09       35-44         Accounting, Banking & Finance
# 19  4/27/2021 11:04:02       25-34  Government and Public Administration
# 28  4/27/2021 11:04:29  65 or over              Property or Construction
# 43  4/27/2021 11:05:08       45-54                     Computing or Tech
# 77  4/27/2021 11:06:07       25-34          Engineering or Manufacturing
#
#                                           Job title    Salary  Compensation  \
# 6                   Manager of Information Services  100000.0           0.0
# 19  Manager of Data Integrity and Prospect Research   65000.0           0.0
# 28                                  Safety Director  104000.0       25000.0
# 43                 senior web application developer   98166.0           0.0
# 77                            Production Technician   65000.0        4000.0
#
#    Currency        Country      State          City  \
# ...

# %%
df_master['Salary'].hist(figsize = (10,10))

df_master[df_master['Gender']=='Woman']['Salary'].hist(figsize=(10,10))

df_master[df_master['Gender']=='Man']['Salary'].hist(figsize=(10,10))
# Out:
# <Axes: >

# %% [markdown]
# man earns more than woman

# %%
df_master[df_master['Gender']=='Woman']['Salary'].hist(figsize=(5,3))
# Out:
# <Axes: >

# %%
df_master[df_master['Gender']=='Man']['Salary'].hist(figsize=(5,3))
# Out:
# <Axes: >

# %%
df_master['Salary'].hist(figsize = (5,3))
# Out:
# <Axes: >

# %%
df_master[df_master['Gender']=='Man']['Salary'].mean(axis=0)
# Out:
# 90437.144106814

# %%
df_master[df_master['Gender']=='Woman']['Salary'].mean(axis=0)
# Out:
# 80082.76110699741

# %%
df_woman = df_master[df_master['Gender']=='Woman']

# %%
numerical_cols = df_master.select_dtypes(include = 'number').columns.tolist()
df_woman[numerical_cols].corr()
# Out:
#                      Salary  Compensation      CGPA  Salary_month_USD  \
# Salary             1.000000      0.413883  0.011891          1.000000
# Compensation       0.413883      1.000000 -0.005318          0.413883
# CGPA               0.011891     -0.005318  1.000000          0.011891
# Salary_month_USD   1.000000      0.413883  0.011891          1.000000
# Special Bonus_GBP  0.000940     -0.000094  0.006638          0.000940
#
#                    Special Bonus_GBP
# Salary                      0.000940
# Compensation               -0.000094
# CGPA                        0.006638
# Salary_month_USD            0.000940
# Special Bonus_GBP           1.000000

# %%
df_man = df_master[df_master['Gender']=='Man']
df_man[numerical_cols].corr()
# Out:
#                      Salary  Compensation      CGPA  Salary_month_USD  \
# Salary             1.000000      0.353905 -0.001814          1.000000
# Compensation       0.353905      1.000000 -0.043991          0.353905
# CGPA              -0.001814     -0.043991  1.000000         -0.001814
# Salary_month_USD   1.000000      0.353905 -0.001814          1.000000
# Special Bonus_GBP  0.003739     -0.012346  0.006694          0.003739
#
#                    Special Bonus_GBP
# Salary                      0.003739
# Compensation               -0.012346
# CGPA                        0.006694
# Salary_month_USD            0.003739
# Special Bonus_GBP           1.000000

# %% [markdown]
# what is the salary in woman of different education/age/experience

# %%
level = 'Master\'s degree'
mean_x = df_man[df_man['Education level']==level]['Salary'].mean()
mean_y = df_woman[df_woman['Education level']==level]['Salary'].mean()

# %%
print(f'man :{mean_x}')
print(f'woman :{mean_y}')
# Out:
# man :94308.19389587073
# woman :82590.60483014862

# %%
edu_level_list = df_woman['Education level'].unique()

# %%
salary_by_edu = []
for edu in edu_level_list:
  salary = df_woman[df_woman['Education level']==edu]['Salary'].mean()
  salary_by_edu.append([edu,salary])

# %%
salary_by_edu = pd.DataFrame(salary_by_edu)

# %%
salary_by_edu.head()
# Out:
#                  0             1
# 0  Master's degree  82590.604830
# 1   College degree  77155.128593
# 2              PhD  92380.408088
# 3     Some college  70428.821705
# 4      High School  64661.540984

# %%
salary_by_edu.plot(kind = 'bar',x = 0,y = 1)
# Out:
# <Axes: xlabel='0'>
